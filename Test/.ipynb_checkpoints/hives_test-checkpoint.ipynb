# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import datetime as dt 

# (defunct) dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')


# File to Load (Remember to change these)
wurz_flow_csv = "data/flow_wurzburg.csv"
wurz_weight_csv = "data/weight_wurzburg.csv"
wurz_temp_csv = "data/temperature_wurzburg.csv"
wurz_humid_csv = "data/humidity_wurzburg.csv"

# Read the hive Data
wurz_flow = pd.read_csv(wurz_flow_csv, parse_dates=['timestamp'], date_parser=pd.to_datetime)
wurz_weight = pd.read_csv(wurz_weight_csv, parse_dates=['timestamp'], date_parser=pd.to_datetime)
wurz_temp = pd.read_csv(wurz_temp_csv, parse_dates=['timestamp'], date_parser=pd.to_datetime)
wurz_humid = pd.read_csv(wurz_humid_csv, parse_dates=['timestamp'], date_parser=pd.to_datetime)


# Combine the data into a single dataset

wurz_3_df = pd.merge(wurz_humid, wurz_temp, on="timestamp", how="left")
wurz_2_df = pd.merge(wurz_3_df, wurz_weight, on="timestamp", how="left")
wurz_hive_df = pd.merge(wurz_2_df, wurz_flow, on="timestamp", how="left")


# Display the data table for preview
wurz_hive_df
# Out:
#                  timestamp   humidity  temperature   weight  flow
# 0      2017-01-01 05:00:00  92.406667    -1.911244      NaN   NaN
# 1      2017-01-01 05:00:00  92.406667    -0.268978      NaN   NaN
# 2      2017-01-01 05:00:00  92.406667     0.553844      NaN   NaN
# 3      2017-01-01 05:00:00  92.406667     3.427489      NaN   NaN
# 4      2017-01-01 05:00:00  92.406667     2.186400      NaN   NaN
# 5      2017-01-01 05:00:00  92.406667     2.848156      NaN   NaN
# 6      2017-01-01 05:00:00  92.406667     4.505489      NaN   NaN
# 7      2017-01-01 05:00:00  92.406667     1.364311      NaN   NaN
# 8      2017-01-01 05:00:00  92.406667     3.199022      NaN   NaN
# 9      2017-01-01 05:00:00  92.406667     1.090467      NaN   NaN
# 10     2017-01-01 06:00:00  92.270000    -1.866717  52.6972   0.0
# 11     2017-01-01 06:00:00  92.270000    -1.866717  52.6972   0.0
# 12     2017-01-01 06:00:00  92.270000    -0.278550  52.6972   0.0
# 13     2017-01-01 06:00:00  92.270000    -0.278550  52.6972   0.0
# 14     2017-01-01 06:00:00  92.270000     0.509700  52.6972   0.0
# 15     2017-01-01 06:00:00  92.270000     0.509700  52.6972   0.0
# 16     2017-01-01 06:00:00  92.270000     3.352567  52.6972   0.0
# 17     2017-01-01 06:00:00  92.270000     3.352567  52.6972   0.0
# 18     2017-01-01 06:00:00  92.270000     2.162150  52.6972   0.0
# 19     2017-01-01 06:00:00  92.270000     2.162150  52.6972   0.0
# 20     2017-01-01 06:00:00  92.270000     2.770200  52.6972   0.0
# 21     2017-01-01 06:00:00  92.270000     2.770200  52.6972   0.0
# 22     2017-01-01 06:00:00  92.270000     3.013883  52.6972   0.0
# 23     2017-01-01 06:00:00  92.270000     3.013883  52.6972   0.0
# 24     2017-01-01 06:00:00  92.270000     4.495117  52.6972   0.0
